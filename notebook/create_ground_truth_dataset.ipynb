# %%
import glob
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np 
import pandas as pd

# %%
collectionNames = [item.split("/")[-1] for item in glob.glob("../input/train/*")]

ground_truth_df = pd.DataFrame()
for collectionName in collectionNames:
    gdfs_each_collectionName = []
    csv_paths = glob.glob(f"../input/train/{collectionName}/*/ground_truth.csv")
    for csv_path in csv_paths:
        gt_df = pd.read_csv(csv_path)
        ground_truth_df = pd.concat([ground_truth_df,gt_df]).reset_index(drop=True)
        break

# %%
ground_truth_df
# Out:
#             collectionName       phoneName  millisSinceGpsEpoch     latDeg  \
# 0      2020-06-04-US-MTV-1  Pixel4XLModded        1275339495434  37.416314
# 1      2020-06-04-US-MTV-1  Pixel4XLModded        1275339496434  37.416314
# 2      2020-06-04-US-MTV-1  Pixel4XLModded        1275339497434  37.416314
# 3      2020-06-04-US-MTV-1  Pixel4XLModded        1275339498434  37.416314
# 4      2020-06-04-US-MTV-1  Pixel4XLModded        1275339499434  37.416314
# ...                    ...             ...                  ...        ...
# 51255  2021-01-04-US-RWC-2        Pixel4XL        1293837080660  37.444461
# 51256  2021-01-04-US-RWC-2        Pixel4XL        1293837081647  37.444461
# 51257  2021-01-04-US-RWC-2        Pixel4XL        1293837082661  37.444461
# 51258  2021-01-04-US-RWC-2        Pixel4XL        1293837083653  37.444461
# 51259  2021-01-04-US-RWC-2        Pixel4XL        1293837084644  37.444461
#
# ...

# %%
ground_truth_df.to_csv('../input/all_ground_truth.csv', index=False)
